# %% [markdown]
# # Lab 5: Порядко-статистические фильтры

# %% [markdown]
# Разработать программу, иллюстрирующую результаты применения порядково-статистичеких фильтров для бинарных и полутоновых изображений для квадратных окон размера 3x3, 5x5, 7x7.

# %%
import matplotlib.pyplot as plt
from functions import *
# %matplotlib inline

# %% [markdown]
# Считали картинки.

# %%
image_binary = read_binary_image('data/image2.png')
image_grey = read_grey_image('data/image5.png')
fig = plt.figure(figsize=(7, 10))
ax1 = fig.add_subplot(221)
ax1.imshow(image_binary, cmap='Greys')
ax2 = fig.add_subplot(222)
ax2.imshow(image_grey, cmap='Greys')

# %% [markdown]
# Применим к бинарному изображению медианные фильтры для квадратных окон размера 3x3, 5x5 и 7x7.

# %%
plt.imshow(calculate_filter_binary_image(image_binary, 3, 5), cmap='Greys')

# %%
plt.imshow(calculate_filter_binary_image(image_binary, 5, 13), cmap='Greys')

# %%
plt.imshow(calculate_filter_binary_image(image_binary, 7, 25), cmap='Greys')

# %% [markdown]
# Теперь тоже самое для полутоновых изображений.

# %%
plt.imshow(calculate_filter_grey_image(image_grey, 3, 5), cmap='Greys')

# %%
plt.imshow(calculate_filter_grey_image(image_grey, 5, 13), cmap='Greys')

# %%
plt.imshow(calculate_filter_grey_image(image_grey, 7, 25), cmap='Greys')
